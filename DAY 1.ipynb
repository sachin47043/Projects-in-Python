# %% [markdown]
# PROJECT 1

# %%
num1 = float(input("Enter first number"))
num2 = float(input("Enter second number"))

print(f'First no is',  {num1}, 'and Second no is', {num2})
print("Addition is simple: ", num1 + num2)
print("Subtraction is simple: ", num1 - num2)
print("Multiplication is simple: ", num1 * num2)
print("Division is simple: ", num1 / num2)
# Out:
# Enter first number 7777777
# Enter second number 7777777
# First no is {7777777.0} and Second no is {7777777.0}
# Addition is simple:  15555554.0
# Subtraction is simple:  0.0
# Multiplication is simple:  60493815061729.0
# Division is simple:  1.0

# %%
c = float(input("Enter the temperature: "))
f = float((c * 1.8)+32)
print("your temperature in fahrenhiet is", f)
# Out:
# Enter the temperature:  10
# your temperature in fahrenhiet is 50.0

# %% [markdown]
# conversion projects

# %% [markdown]
# kilogram to pound

# %%
k = float(input("Enter the weight value in kilogram:"))
p = (2.205*k)
print("Your", k , "in pounds is", p)
# Out:
# Enter the weight value in kilogram: 5
# Your 5.0 in pounds is 11.025

# %% [markdown]
# Hours to minutes

# %%
h = int(input("Enter the time in hours:"))
m = (h*60)
print("Your time in minutes: ", m,"min")
# Out:
# Enter the time in hours: 2
# Your time in minutes:  120 min

# %% [markdown]
# Doller to Rupees

# %%
d = int(input("Enter the currency in dollar: "))
r = (d*88.50)
print("Your currency in rupees: Rs", r)
# Out:
# Enter the currency in dollar:  2
# Your currency in rupees: Rs 177.0
